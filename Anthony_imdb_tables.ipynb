# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
awdf_tratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')

awdf_tratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
awdf_tratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
awdf_tbasics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')

awdf_tbasics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
awdf_tbasics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
leftjoin_rating_basics = awdf_tratings.set_index('tconst').join(awdf_tbasics.set_index('tconst'), how='left', lsuffix='1', rsuffix='2')

leftjoin_rating_basics

# left joining on the ratings and basics tables since we care about the ratings of movies more than just movies that may or may not have a
# rating in these data sets. Every rating has a movie associated with it, but not vice versa
# Out:
#             averagerating  numvotes  \
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21
# ...                   ...       ...
# tt9805820             8.1        25
# tt9844256             7.5        24
# tt9851050             4.7        14
# tt9886934             7.0         5
# tt9894098             6.3       128
#
#                                                 primary_title  \
# tconst
# tt10356526                                   Laiye Je Yaarian
# tt10384606                                         Borderless
# tt1042974                                           Just Inès
# tt1043726                              The Legend of Hercules
# tt1060240                                           Até Onde?
# ...                                                       ...
# tt9805820                                               Caisa
# tt9844256   Code Geass: Lelouch of the Rebellion - Glorifi...
# tt9851050                                             Sisters
# tt9886934                                   The Projectionist
# tt9894098                                              Sathru
#
#                                               original_title  start_year  \
# tconst
# tt10356526                                  Laiye Je Yaarian        2019
# tt10384606                                        Borderless        2019
# tt1042974                                          Just Inès        2010
# tt1043726                             The Legend of Hercules        2014
# tt1060240                                          Até Onde?        2011
# ...                                                      ...         ...
# tt9805820                                              Caisa        2018
# tt9844256   Code Geass: Lelouch of the Rebellion Episode III        2018
# tt9851050                                            Sisters        2019
# tt9886934                                  The Projectionist        2019
# tt9894098                                             Sathru        2019
#
#             runtime_minutes                    genres
# tconst
# tt10356526            117.0                   Romance
# tt10384606             87.0               Documentary
# tt1042974              90.0                     Drama
# tt1043726              99.0  Action,Adventure,Fantasy
# tt1060240              73.0          Mystery,Thriller
# ...                     ...                       ...
# tt9805820              84.0               Documentary
# tt9844256             120.0   Action,Animation,Sci-Fi
# tt9851050               NaN              Action,Drama
# tt9886934              81.0               Documentary
# tt9894098             129.0                  Thriller
#
# [73856 rows x 7 columns]

# %%
leftjoin_rating_basics.duplicated().sum() #No duplicates listed
# Out:
# 0

# %%
leftjoin_rating_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73856 entries, tt10356526 to tt9894098
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   averagerating    73856 non-null  float64
#  1   numvotes         73856 non-null  int64
#  2   primary_title    73856 non-null  object
#  3   original_title   73856 non-null  object
#  4   start_year       73856 non-null  int64
#  5   runtime_minutes  66236 non-null  float64
#  6   genres           73052 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 7.0+ MB

# %%
# sorted_numvotes = leftjoin_rating_basics.sort_values(by='numvotes', ascending=False)

sorted_numvotes.head(100) #top movies by number of votes (people who've seen the movie)
# Out:
#            averagerating  numvotes                  primary_title  \
# tconst
# tt1375666            8.8   1841066                      Inception
# tt1345836            8.4   1387769          The Dark Knight Rises
# tt0816692            8.6   1299334                   Interstellar
# tt1853728            8.4   1211405               Django Unchained
# tt0848228            8.1   1183655                   The Avengers
# ...                  ...       ...                            ...
# tt3253232            5.0       492                The Bounce Back
# tt2185846            3.0       492  Morangos com Açúcar - O Filme
# tt1707384            6.2       492              High School Debut
# tt3157114            6.7       492                    Lotoman 003
# tt4547076            4.9       492              My Guardian Angel
#
#                           original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                      Inception        2010            148.0
# tt1345836          The Dark Knight Rises        2012            164.0
# tt0816692                   Interstellar        2014            169.0
# tt1853728               Django Unchained        2012            165.0
# tt0848228                   The Avengers        2012            143.0
# ...                                  ...         ...              ...
# tt3253232                The Bounce Back        2016            104.0
# tt2185846  Morangos com Açúcar - O Filme        2012             97.0
# tt1707384                     Kôkô debyû        2011             93.0
# tt3157114                    Lotoman 003        2014              NaN
# tt4547076              My Guardian Angel        2016            100.0
#
#                             genres
# tconst
# tt1375666  Action,Adventure,Sci-Fi
# tt1345836          Action,Thriller
# tt0816692   Adventure,Drama,Sci-Fi
# tt1853728            Drama,Western
# tt0848228  Action,Adventure,Sci-Fi
# ...                            ...
# tt3253232           Comedy,Romance
# tt2185846      Comedy,Drama,Family
# tt1707384           Comedy,Romance
# tt3157114                   Comedy
# tt4547076                 Thriller
#
# [14000 rows x 7 columns]

# %%
top_numgenres = sorted_numvotes.head(100).copy()

top_numgenres
# Out:
#            averagerating  numvotes                    primary_title  \
# tconst
# tt1375666            8.8   1841066                        Inception
# tt1345836            8.4   1387769            The Dark Knight Rises
# tt0816692            8.6   1299334                     Interstellar
# tt1853728            8.4   1211405                 Django Unchained
# tt0848228            8.1   1183655                     The Avengers
# ...                  ...       ...                              ...
# tt0470752            7.7    424542                       Ex Machina
# tt1659337            8.0    422671  The Perks of Being a Wallflower
# tt1800241            7.2    418221                  American Hustle
# tt2872718            7.9    404476                     Nightcrawler
# tt1291584            8.2    403755                          Warrior
#
#                             original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                        Inception        2010            148.0
# tt1345836            The Dark Knight Rises        2012            164.0
# tt0816692                     Interstellar        2014            169.0
# tt1853728                 Django Unchained        2012            165.0
# tt0848228                     The Avengers        2012            143.0
# ...                                    ...         ...              ...
# tt0470752                       Ex Machina        2014            108.0
# tt1659337  The Perks of Being a Wallflower        2012            103.0
# tt1800241                  American Hustle        2013            138.0
# tt2872718                     Nightcrawler        2014            117.0
# tt1291584                          Warrior        2011            140.0
#
#                             genres
# tconst
# tt1375666  Action,Adventure,Sci-Fi
# tt1345836          Action,Thriller
# tt0816692   Adventure,Drama,Sci-Fi
# tt1853728            Drama,Western
# tt0848228  Action,Adventure,Sci-Fi
# ...                            ...
# tt0470752     Drama,Mystery,Sci-Fi
# tt1659337                    Drama
# tt1800241              Crime,Drama
# tt2872718     Crime,Drama,Thriller
# tt1291584              Drama,Sport
#
# [100 rows x 7 columns]

# %%
top_numgenres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, tt1375666 to tt1291584
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   averagerating    100 non-null    float64
#  1   numvotes         100 non-null    int64
#  2   primary_title    100 non-null    object
#  3   original_title   100 non-null    object
#  4   start_year       100 non-null    int64
#  5   runtime_minutes  100 non-null    float64
#  6   genres           100 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 6.2+ KB

# %%
top_numgenres
# Out:
#            averagerating  numvotes                    primary_title  \
# tconst
# tt1375666            8.8   1841066                        Inception
# tt1345836            8.4   1387769            The Dark Knight Rises
# tt0816692            8.6   1299334                     Interstellar
# tt1853728            8.4   1211405                 Django Unchained
# tt0848228            8.1   1183655                     The Avengers
# ...                  ...       ...                              ...
# tt0470752            7.7    424542                       Ex Machina
# tt1659337            8.0    422671  The Perks of Being a Wallflower
# tt1800241            7.2    418221                  American Hustle
# tt2872718            7.9    404476                     Nightcrawler
# tt1291584            8.2    403755                          Warrior
#
#                             original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                        Inception        2010            148.0
# tt1345836            The Dark Knight Rises        2012            164.0
# tt0816692                     Interstellar        2014            169.0
# tt1853728                 Django Unchained        2012            165.0
# tt0848228                     The Avengers        2012            143.0
# ...                                    ...         ...              ...
# tt0470752                       Ex Machina        2014            108.0
# tt1659337  The Perks of Being a Wallflower        2012            103.0
# tt1800241                  American Hustle        2013            138.0
# tt2872718                     Nightcrawler        2014            117.0
# tt1291584                          Warrior        2011            140.0
#
#                             genres
# tconst
# tt1375666  Action,Adventure,Sci-Fi
# tt1345836          Action,Thriller
# tt0816692   Adventure,Drama,Sci-Fi
# tt1853728            Drama,Western
# tt0848228  Action,Adventure,Sci-Fi
# ...                            ...
# tt0470752     Drama,Mystery,Sci-Fi
# tt1659337                    Drama
# tt1800241              Crime,Drama
# tt2872718     Crime,Drama,Thriller
# tt1291584              Drama,Sport
#
# [100 rows x 7 columns]

# %%
top_numgenres.duplicated().sum() #no duplicates
# Out:
# 0

# %%
top_numgenres = pd.concat([top_numgenres, top_numgenres['genres'].str.split(',', expand=True)], axis=1)
#split 'genres' into separate columns for each comma-separated genre listed
top_numgenres
# Out:
#            averagerating  numvotes                    primary_title  \
# tconst
# tt1375666            8.8   1841066                        Inception
# tt1345836            8.4   1387769            The Dark Knight Rises
# tt0816692            8.6   1299334                     Interstellar
# tt1853728            8.4   1211405                 Django Unchained
# tt0848228            8.1   1183655                     The Avengers
# ...                  ...       ...                              ...
# tt0470752            7.7    424542                       Ex Machina
# tt1659337            8.0    422671  The Perks of Being a Wallflower
# tt1800241            7.2    418221                  American Hustle
# tt2872718            7.9    404476                     Nightcrawler
# tt1291584            8.2    403755                          Warrior
#
#                             original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                        Inception        2010            148.0
# tt1345836            The Dark Knight Rises        2012            164.0
# tt0816692                     Interstellar        2014            169.0
# tt1853728                 Django Unchained        2012            165.0
# tt0848228                     The Avengers        2012            143.0
# ...                                    ...         ...              ...
# tt0470752                       Ex Machina        2014            108.0
# tt1659337  The Perks of Being a Wallflower        2012            103.0
# tt1800241                  American Hustle        2013            138.0
# tt2872718                     Nightcrawler        2014            117.0
# tt1291584                          Warrior        2011            140.0
#
#                             genres          0          1         2
# tconst
# tt1375666  Action,Adventure,Sci-Fi     Action  Adventure    Sci-Fi
# tt1345836          Action,Thriller     Action   Thriller      None
# tt0816692   Adventure,Drama,Sci-Fi  Adventure      Drama    Sci-Fi
# tt1853728            Drama,Western      Drama    Western      None
# tt0848228  Action,Adventure,Sci-Fi     Action  Adventure    Sci-Fi
# ...                            ...        ...        ...       ...
# tt0470752     Drama,Mystery,Sci-Fi      Drama    Mystery    Sci-Fi
# tt1659337                    Drama      Drama       None      None
# tt1800241              Crime,Drama      Crime      Drama      None
# tt2872718     Crime,Drama,Thriller      Crime      Drama  Thriller
# tt1291584              Drama,Sport      Drama      Sport      None
#
# [100 rows x 10 columns]

# %%
#drop 'genres' column

top_numgenres.drop('genres',axis=1, inplace=True)

top_numgenres
# Out:
#            averagerating  numvotes                    primary_title  \
# tconst
# tt1375666            8.8   1841066                        Inception
# tt1345836            8.4   1387769            The Dark Knight Rises
# tt0816692            8.6   1299334                     Interstellar
# tt1853728            8.4   1211405                 Django Unchained
# tt0848228            8.1   1183655                     The Avengers
# ...                  ...       ...                              ...
# tt0470752            7.7    424542                       Ex Machina
# tt1659337            8.0    422671  The Perks of Being a Wallflower
# tt1800241            7.2    418221                  American Hustle
# tt2872718            7.9    404476                     Nightcrawler
# tt1291584            8.2    403755                          Warrior
#
#                             original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                        Inception        2010            148.0
# tt1345836            The Dark Knight Rises        2012            164.0
# tt0816692                     Interstellar        2014            169.0
# tt1853728                 Django Unchained        2012            165.0
# tt0848228                     The Avengers        2012            143.0
# ...                                    ...         ...              ...
# tt0470752                       Ex Machina        2014            108.0
# tt1659337  The Perks of Being a Wallflower        2012            103.0
# tt1800241                  American Hustle        2013            138.0
# tt2872718                     Nightcrawler        2014            117.0
# tt1291584                          Warrior        2011            140.0
#
#                    0          1         2
# tconst
# tt1375666     Action  Adventure    Sci-Fi
# tt1345836     Action   Thriller      None
# tt0816692  Adventure      Drama    Sci-Fi
# tt1853728      Drama    Western      None
# tt0848228     Action  Adventure    Sci-Fi
# ...              ...        ...       ...
# tt0470752      Drama    Mystery    Sci-Fi
# tt1659337      Drama       None      None
# tt1800241      Crime      Drama      None
# tt2872718      Crime      Drama  Thriller
# tt1291584      Drama      Sport      None
#
# [100 rows x 9 columns]

# %%
top_numgenres.rename(columns = {0:'genre 1', 1:'genre 2', 2:'genre 3'}, inplace=True)

top_numgenres
# Out:
#            averagerating  numvotes                    primary_title  \
# tconst
# tt1375666            8.8   1841066                        Inception
# tt1345836            8.4   1387769            The Dark Knight Rises
# tt0816692            8.6   1299334                     Interstellar
# tt1853728            8.4   1211405                 Django Unchained
# tt0848228            8.1   1183655                     The Avengers
# ...                  ...       ...                              ...
# tt0470752            7.7    424542                       Ex Machina
# tt1659337            8.0    422671  The Perks of Being a Wallflower
# tt1800241            7.2    418221                  American Hustle
# tt2872718            7.9    404476                     Nightcrawler
# tt1291584            8.2    403755                          Warrior
#
#                             original_title  start_year  runtime_minutes  \
# tconst
# tt1375666                        Inception        2010            148.0
# tt1345836            The Dark Knight Rises        2012            164.0
# tt0816692                     Interstellar        2014            169.0
# tt1853728                 Django Unchained        2012            165.0
# tt0848228                     The Avengers        2012            143.0
# ...                                    ...         ...              ...
# tt0470752                       Ex Machina        2014            108.0
# tt1659337  The Perks of Being a Wallflower        2012            103.0
# tt1800241                  American Hustle        2013            138.0
# tt2872718                     Nightcrawler        2014            117.0
# tt1291584                          Warrior        2011            140.0
#
#              genre 1    genre 2   genre 3
# tconst
# tt1375666     Action  Adventure    Sci-Fi
# tt1345836     Action   Thriller      None
# tt0816692  Adventure      Drama    Sci-Fi
# tt1853728      Drama    Western      None
# tt0848228     Action  Adventure    Sci-Fi
# ...              ...        ...       ...
# tt0470752      Drama    Mystery    Sci-Fi
# tt1659337      Drama       None      None
# tt1800241      Crime      Drama      None
# tt2872718      Crime      Drama  Thriller
# tt1291584      Drama      Sport      None
#
# [100 rows x 9 columns]

# %%
genre_list = ['genre 1', 'genre 2', 'genre 3']
top_numgenres_count = {}

for var in genre_list:
    for genre in top_numgenres[var]:
        if genre != None:
            top_numgenres_count[genre] = top_numgenres_count.get(genre, 0) + 1

# %%
top_numgenres_count
# Out:
# {'Action': 54,
#  'Adventure': 57,
#  'Drama': 36,
#  'Biography': 8,
#  'Mystery': 11,
#  'Comedy': 20,
#  'Crime': 11,
#  'Animation': 5,
#  'Thriller': 13,
#  'Western': 1,
#  'Family': 2,
#  'Sci-Fi': 36,
#  'Music': 2,
#  'Fantasy': 16,
#  'Romance': 4,
#  'Sport': 1,
#  'History': 3,
#  'Horror': 1}

# %%
df_top_genres = pd.DataFrame({'top genres': [var for var in top_numgenres_count.keys()],
                              'values': [var for var in top_numgenres_count.values()]})

df_top_genres = df_top_genres.sort_values(by='values', ascending=False)

df_top_genres
# Out:
#    top genres  values
# 1   Adventure      57
# 0      Action      54
# 2       Drama      36
# 11     Sci-Fi      36
# 5      Comedy      20
# 13    Fantasy      16
# 8    Thriller      13
# 4     Mystery      11
# 6       Crime      11
# 3   Biography       8
# 7   Animation       5
# 14    Romance       4
# 16    History       3
# 10     Family       2
# 12      Music       2
# 9     Western       1
# 15      Sport       1
# 17     Horror       1

# %%
# fig, ax = plt.subplots(figsize=(10,6))
ax = df_top_genres.plot.bar(x='top genres', y='values', legend=None, figsize=(10,6))
plt.title('Most Common Genres of the Top 100 Movies')
ax.set(xlabel=None)
plt.savefig('Genres_Most_Common', bbox_inches='tight')

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.set_style("white")
ax = sns.barplot(x='top genres', y='values', data= df_top_genres, color= '#F65314')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 50);
ax.set(xlabel=None)
ax.set_ylabel(ylabel=None)
ax.set_title('Most Common Genres of the Top 100 Movies');

# %%
x = top_numgenres['averagerating']
y = top_numgenres['numvotes']
                                       
plt.scatter(x, y)
plt.title('Relationship Between Number of Votes \n and the Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Number of Votes (in millions)')
plt.axis([6.8, 9.0, 600000, 2000000])
# Out:
# (6.8, 9.0, 600000.0, 2000000.0)

# %%
top_numgenres.describe() 

# mean runtime of the top 20 movies by number of votes is a little over 138 minutes, which isn't too far off from the median time of
# 140 minutes
# Out:
#        averagerating      numvotes   start_year  runtime_minutes
# count     100.000000  1.000000e+02   100.000000        100.00000
# mean        7.671000  6.065208e+05  2013.250000        127.99000
# std         0.517823  2.247789e+05     2.212796         20.00227
# min         6.000000  4.037550e+05  2010.000000         91.00000
# 25%         7.300000  4.715730e+05  2011.750000        113.75000
# 50%         7.700000  5.401670e+05  2013.000000        127.50000
# 75%         8.000000  6.596660e+05  2015.000000        141.25000
# max         8.800000  1.841066e+06  2019.000000        181.00000
